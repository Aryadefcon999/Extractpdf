# %%
from PyPDF2 import PdfFileReader, PdfFileWriter
import PyPDF2

# %%
#UnicodeDecodeError: 
#'charmap' codec can't decode byte 0x9d in position 132: character maps to <undefined>
#WE have to use the "rb"(Reading in Binary)
pdf =open('infosys-ar-22.pdf','rb')
page_1_object= PyPDF2.PdfFileReader(pdf)
page_1_object.numPages
# Out:
# 363

# %%
    # Create pdf file reader object
    pdf = PdfFileReader('infosys-ar-22.pdf')
    # TWO STEPS TO EXTRACT TEXT 
    # Step 1: Grab the Page(s)
    page_1_object = pdf.getPage(119)
    

    # Step 2: Extract Text
    page_1_text = page_1_object.extractText()
    print("Data from  126pg\n",page_1_text,end="\n")
    page_2_object = pdf.getPage(126)
    page_2_text = page_2_object.extract_text()
    
    print("Data from the page 126\n",page_2_text)
# Out:
# Data from  126pg
#  Infosys Integrated Annual Report 2021-22 153
# Introduction Delivering
# valueGovernanceBRSRStatutory
# reports
#
#
# CG Report
# Financial
# statementsStrategy
# reviewApproaching
# value creation
#
# Attendance details of the stakeholders relationship committee
#
#
# Stakeholders relationship committee meeting
# Name of the directorsCommittee meeting dates
# D. Sundaram
# Bobby Parikh
# U. B. Pravin Rao
# (1)
# Chitra Nayak
#  Held
# during
# tenure% of
# attendance
# 4
# 4
# 3
# 44
# 4
# 3
# 4Apr 07, 202112
# 100
# 100
# 100
# 100
# Attendance percentage 100%
# Attended through video conferenceAttendedJul 06, 2021
# 100%3
# Oct 07, 2021
# 100%4
# Jan 04, 2022
# 100%
#
#
# (1)
#  Ceased to be a member of the Committee due to retirement effective December 12, 2021
# Shareholding as on March 31, 2022Complaints received and resolved during the year
# ended March 31, 2022
#
# Shareholding mode
#
# DematerializedPhysical
#  99.88%0.12%
# % Equity
#
# ...

# %%
file_path = 'infosys-ar-22.pdf'
pdf = Pd
